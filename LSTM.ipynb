# %% [markdown]
# # Import all the required libraries
#
# ---

# %%
import pandas as pd
import datetime as dt
from datetime import date
import matplotlib.pyplot as plt
import yfinance as yf
import numpy as np
import tensorflow as tf

# %% [markdown]
# # Define start day to fetch the dataset from the yahoo finance library
#
# ---

# %%
START = "2010-01-01"
TODAY = date.today().strftime("%Y-%m-%d")

# Define a function to load the dataset

def load_data(ticker):
    data = yf.download(ticker, START, TODAY)
    data.reset_index(inplace=True)
    return data

# %%
data = load_data('TCS.NS')
df=data
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                       Date   Adj Close       Close        High  \
# Ticker                                TCS.NS      TCS.NS      TCS.NS
# 0      2010-01-04 00:00:00+00:00  283.344543  375.825012  379.450012
# 1      2010-01-05 00:00:00+00:00  283.419861  375.924988  379.774994
# 2      2010-01-06 00:00:00+00:00  277.011597  367.424988  376.100006
# 3      2010-01-07 00:00:00+00:00  269.302643  357.200012  369.700012
# 4      2010-01-08 00:00:00+00:00  263.798950  349.899994  359.250000
#
# Price          Low        Open   Volume
# Ticker      TCS.NS      TCS.NS   TCS.NS
# 0       374.524994  377.399994  1963682
# 1       373.274994  377.500000  2014488
# 2       366.500000  375.924988  3349176
# 3       355.500000  367.750000  6474892
# 4       348.250000  358.000000  6048178

# %%
df = df.drop(['Date', 'Adj Close'], axis = 1)
df.head()
# Out:
# <ipython-input-4-8097d146b7ad>:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   df = df.drop(['Date', 'Adj Close'], axis = 1)
# Price        Close        High         Low        Open   Volume
# Ticker      TCS.NS      TCS.NS      TCS.NS      TCS.NS   TCS.NS
# 0       375.825012  379.450012  374.524994  377.399994  1963682
# 1       375.924988  379.774994  373.274994  377.500000  2014488
# 2       367.424988  376.100006  366.500000  375.924988  3349176
# 3       357.200012  369.700012  355.500000  367.750000  6474892
# 4       349.899994  359.250000  348.250000  358.000000  6048178

# %% [markdown]
# Visualizing Closing Price

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['Close'])
plt.title("TCS India Stock Price")
plt.xlabel("Date")
plt.ylabel("Price (INR)")
plt.grid(True)
plt.show()

# %%
df
# Out:
# Price         Close         High          Low         Open   Volume
# Ticker       TCS.NS       TCS.NS       TCS.NS       TCS.NS   TCS.NS
# 0        375.825012   379.450012   374.524994   377.399994  1963682
# 1        375.924988   379.774994   373.274994   377.500000  2014488
# 2        367.424988   376.100006   366.500000   375.924988  3349176
# 3        357.200012   369.700012   355.500000   367.750000  6474892
# 4        349.899994   359.250000   348.250000   358.000000  6048178
# ...             ...          ...          ...          ...      ...
# 3651    4079.850098  4139.950195  4070.000000  4132.600098  1595450
# 3652    4015.500000  4089.800049  4006.350098  4066.000000  1928049
# 3653    4066.250000  4113.549805  3995.149902  3999.600098  1966476
# 3654    4047.899902  4079.000000  4004.000000  4004.000000  2676744
# 3655    4057.550049  4092.000000  4032.699951  4057.050049  1759676
#
# [3656 rows x 5 columns]

# %% [markdown]
# # Plotting moving averages of 100 day
#
# ---

# %%
ma100 = df.Close.rolling(100).mean()
ma100
# Out:
# Ticker       TCS.NS
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 3651    4185.645493
# 3652    4187.763994
# 3653    4191.065493
# 3654    4194.834993
# 3655    4198.381992
#
# [3656 rows x 1 columns]

# %%
plt.figure(figsize = (12,6))
plt.plot(df.Close)
plt.plot(ma100, 'r')
plt.grid(True)
plt.title('Graph Of Moving Averages Of 100 Days')
# Out:
# Text(0.5, 1.0, 'Graph Of Moving Averages Of 100 Days')

# %% [markdown]
# # Defining 200 days moving averages and plotting comparision graph with 100 days moving averages
#
# ---

# %%
ma200 = df.Close.rolling(200).mean()
ma200
# Out:
# Ticker       TCS.NS
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 3651    4061.626750
# 3652    4062.704751
# 3653    4064.069001
# 3654    4065.253000
# 3655    4066.624751
#
# [3656 rows x 1 columns]

# %%
plt.figure(figsize = (12,6))
plt.plot(df.Close)
plt.plot(ma100, 'r')
plt.plot(ma200, 'g')
plt.grid(True)
plt.title('Comparision Of 100 Days And 200 Days Moving Averages')
# Out:
# Text(0.5, 1.0, 'Comparision Of 100 Days And 200 Days Moving Averages')

# %%
df.shape
# Out:
# (3656, 5)

# %% [markdown]
# # Spliting the dataset into training (70%) and testing (30%) set

# %%
# Splitting data into training and testing

train = pd.DataFrame(data[0:int(len(data)*0.70)])
test = pd.DataFrame(data[int(len(data)*0.70): int(len(data))])

print(train.shape)
print(test.shape)
# Out:
# (2559, 7)
# (1097, 7)

# %%
train.head()
# Out:
# Price                       Date   Adj Close       Close        High  \
# Ticker                                TCS.NS      TCS.NS      TCS.NS
# 0      2010-01-04 00:00:00+00:00  283.344543  375.825012  379.450012
# 1      2010-01-05 00:00:00+00:00  283.419861  375.924988  379.774994
# 2      2010-01-06 00:00:00+00:00  277.011597  367.424988  376.100006
# 3      2010-01-07 00:00:00+00:00  269.302643  357.200012  369.700012
# 4      2010-01-08 00:00:00+00:00  263.798950  349.899994  359.250000
#
# Price          Low        Open   Volume
# Ticker      TCS.NS      TCS.NS   TCS.NS
# 0       374.524994  377.399994  1963682
# 1       373.274994  377.500000  2014488
# 2       366.500000  375.924988  3349176
# 3       355.500000  367.750000  6474892
# 4       348.250000  358.000000  6048178

# %%
test.head()
# Out:
# Price                       Date    Adj Close        Close         High  \
# Ticker                                 TCS.NS       TCS.NS       TCS.NS
# 2559   2020-05-27 00:00:00+00:00  1849.367065  2005.300049  2010.000000
# 2560   2020-05-28 00:00:00+00:00  1848.444824  2004.300049  2014.000000
# 2561   2020-05-29 00:00:00+00:00  1818.979248  1972.349976  2002.650024
# 2562   2020-06-01 00:00:00+00:00  1886.210449  2045.250000  2060.000000
# 2563   2020-06-02 00:00:00+00:00  1887.962891  2047.150024  2081.000000
#
# Price           Low         Open   Volume
# Ticker       TCS.NS       TCS.NS   TCS.NS
# 2559    1941.250000  1959.000000  3482160
# 2560    1971.300049  1988.500000  3475681
# 2561    1962.400024  1982.000000  7237735
# 2562    1981.099976  1990.000000  3747773
# 2563    2040.050049  2060.199951  2443886

# %% [markdown]
# # Using MinMax scaler for normalization of the dataset
#
# ---

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0,1))

# %%
train_close = train.iloc[:, 4:5].values
test_close = test.iloc[:, 4:5].values

# %%
data_training_array = scaler.fit_transform(train_close)
data_training_array
# Out:
# array([[0.01671754],
#        [0.01606246],
#        [0.01251195],
#        ...,
#        [0.83772452],
#        [0.84825813],
#        [0.82926092]])

# %%
x_train = []
y_train = []

for i in range(100, data_training_array.shape[0]):
    x_train.append(data_training_array[i-100: i])
    y_train.append(data_training_array[i, 0])

x_train, y_train = np.array(x_train), np.array(y_train)

# %%
x_train.shape
# Out:
# (2459, 100, 1)

# %% [markdown]
# # ML Model (LSTM)
#
# ---

# %%
from tensorflow.keras.layers import Dense, Dropout, LSTM
from tensorflow.keras.models import Sequential

# %%
model = Sequential()
model.add(LSTM(units = 50, activation = 'relu', return_sequences=True
              ,input_shape = (x_train.shape[1], 1)))
model.add(Dropout(0.2))


model.add(LSTM(units = 60, activation = 'relu', return_sequences=True))
model.add(Dropout(0.3))


model.add(LSTM(units = 80, activation = 'relu', return_sequences=True))
model.add(Dropout(0.4))


model.add(LSTM(units = 120, activation = 'relu'))
model.add(Dropout(0.5))

model.add(Dense(units = 1))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 100, 50)             │          10,400 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 100, 50)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 100, 60)             │          26,640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 100, 60)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_2 (LSTM)                        │ (None, 100, 80)             │          45,120 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 100, 80)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_3 (LSTM)                        │ (None, 120)                 │          96,480 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 120)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │             121 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 178,761 (698.29 KB)
#  Trainable params: 178,761 (698.29 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # Training the model
#
# ---

# %%
import tensorflow as tf
model.compile(optimizer = 'adam', loss = 'mean_squared_error', metrics=[tf.keras.metrics.MeanAbsoluteError()])
model.fit(x_train, y_train,epochs = 100)
# Out:
# Epoch 1/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 28s 159ms/step - loss: 0.1111 - mean_absolute_error: 0.2344
# Epoch 2/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 22s 45ms/step - loss: 0.0083 - mean_absolute_error: 0.0643
# Epoch 3/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - loss: 0.0077 - mean_absolute_error: 0.0624
# Epoch 4/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - loss: 0.0080 - mean_absolute_error: 0.0610
# Epoch 5/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - loss: 0.0076 - mean_absolute_error: 0.0595
# Epoch 6/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - loss: 0.0058 - mean_absolute_error: 0.0527
# Epoch 7/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - loss: 0.0065 - mean_absolute_error: 0.0545
# Epoch 8/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 44ms/step - loss: 0.0056 - mean_absolute_error: 0.0516
# Epoch 9/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - loss: 0.0057 - mean_absolute_error: 0.0523
# Epoch 10/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - loss: 0.0044 - mean_absolute_error: 0.0459
# Epoch 11/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - loss: 0.0050 - mean_absolute_error: 0.0493
# Epoch 12/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 0.0049 - mean_absolute_error: 0.0478
# Epoch 13/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - loss: 0.0046 - mean_absolute_error: 0.0461
# Epoch 14/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - loss: 0.0048 - mean_absolute_error: 0.0480
# Epoch 15/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0034 - mean_absolute_error: 0.0402
# Epoch 16/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 0.0042 - mean_absolute_error: 0.0447
# Epoch 17/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - loss: 0.0043 - mean_absolute_error: 0.0441
# Epoch 18/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0045 - mean_absolute_error: 0.0464
# Epoch 19/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - loss: 0.0038 - mean_absolute_error: 0.0431
# Epoch 20/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - loss: 0.0033 - mean_absolute_error: 0.0405
# Epoch 21/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0037 - mean_absolute_error: 0.0430
# Epoch 22/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - loss: 0.0034 - mean_absolute_error: 0.0405
# Epoch 23/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - loss: 0.0036 - mean_absolute_error: 0.0408
# Epoch 24/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0031 - mean_absolute_error: 0.0385
# Epoch 25/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 0.0029 - mean_absolute_error: 0.0377
# Epoch 26/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - loss: 0.0032 - mean_absolute_error: 0.0396
# Epoch 27/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0032 - mean_absolute_error: 0.0397
# Epoch 28/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 0.0028 - mean_absolute_error: 0.0379
# Epoch 29/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 44ms/step - loss: 0.0030 - mean_absolute_error: 0.0378
# Epoch 30/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - loss: 0.0029 - mean_absolute_error: 0.0377
# Epoch 31/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - loss: 0.0028 - mean_absolute_error: 0.0374
# Epoch 32/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - loss: 0.0029 - mean_absolute_error: 0.0378
# Epoch 33/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - loss: 0.0029 - mean_absolute_error: 0.0379
# Epoch 34/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0024 - mean_absolute_error: 0.0361
# Epoch 35/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0022 - mean_absolute_error: 0.0344
# Epoch 36/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0028 - mean_absolute_error: 0.0372
# Epoch 37/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - loss: 0.0028 - mean_absolute_error: 0.0368
# Epoch 38/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - loss: 0.0027 - mean_absolute_error: 0.0367
# Epoch 39/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 47ms/step - loss: 0.0024 - mean_absolute_error: 0.0353
# Epoch 40/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0029 - mean_absolute_error: 0.0380
# Epoch 41/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0025 - mean_absolute_error: 0.0359
# Epoch 42/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 47ms/step - loss: 0.0026 - mean_absolute_error: 0.0358
# Epoch 43/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - loss: 0.0025 - mean_absolute_error: 0.0352
# Epoch 44/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 44ms/step - loss: 0.0023 - mean_absolute_error: 0.0343
# Epoch 45/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - loss: 0.0025 - mean_absolute_error: 0.0365
# Epoch 46/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 44ms/step - loss: 0.0025 - mean_absolute_error: 0.0355
# Epoch 47/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - loss: 0.0024 - mean_absolute_error: 0.0355
# Epoch 48/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - loss: 0.0024 - mean_absolute_error: 0.0354
# Epoch 49/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0026 - mean_absolute_error: 0.0368
# Epoch 50/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0024 - mean_absolute_error: 0.0351
# Epoch 51/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - loss: 0.0022 - mean_absolute_error: 0.0342
# Epoch 52/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - loss: 0.0021 - mean_absolute_error: 0.0330
# Epoch 53/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 0.0023 - mean_absolute_error: 0.0336
# Epoch 54/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 44ms/step - loss: 0.0021 - mean_absolute_error: 0.0339
# Epoch 55/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - loss: 0.0023 - mean_absolute_error: 0.0348
# Epoch 56/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - loss: 0.0023 - mean_absolute_error: 0.0339
# Epoch 57/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0026 - mean_absolute_error: 0.0349
# Epoch 58/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0024 - mean_absolute_error: 0.0349
# Epoch 59/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - loss: 0.0022 - mean_absolute_error: 0.0341
# Epoch 60/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0021 - mean_absolute_error: 0.0328
# Epoch 61/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - loss: 0.0024 - mean_absolute_error: 0.0346
# Epoch 62/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - loss: 0.0023 - mean_absolute_error: 0.0340
# Epoch 63/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - loss: 0.0023 - mean_absolute_error: 0.0336
# Epoch 64/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - loss: 0.0023 - mean_absolute_error: 0.0340
# Epoch 65/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - loss: 0.0022 - mean_absolute_error: 0.0335
# Epoch 66/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - loss: 0.0023 - mean_absolute_error: 0.0343
# Epoch 67/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 44ms/step - loss: 0.0026 - mean_absolute_error: 0.0363
# Epoch 68/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0023 - mean_absolute_error: 0.0350
# Epoch 69/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - loss: 0.0024 - mean_absolute_error: 0.0353
# Epoch 70/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - loss: 0.0023 - mean_absolute_error: 0.0341
# Epoch 71/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - loss: 0.0025 - mean_absolute_error: 0.0360
# Epoch 72/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0022 - mean_absolute_error: 0.0341
# Epoch 73/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - loss: 0.0023 - mean_absolute_error: 0.0341
# Epoch 74/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - loss: 0.0022 - mean_absolute_error: 0.0343
# Epoch 75/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0020 - mean_absolute_error: 0.0327
# Epoch 76/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - loss: 0.0023 - mean_absolute_error: 0.0346
# Epoch 77/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 0.0022 - mean_absolute_error: 0.0341
# Epoch 78/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0023 - mean_absolute_error: 0.0341
# Epoch 79/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0021 - mean_absolute_error: 0.0332
# Epoch 80/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - loss: 0.0021 - mean_absolute_error: 0.0334
# Epoch 81/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - loss: 0.0021 - mean_absolute_error: 0.0330
# Epoch 82/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0022 - mean_absolute_error: 0.0329
# Epoch 83/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - loss: 0.0024 - mean_absolute_error: 0.0355
# Epoch 84/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - loss: 0.0022 - mean_absolute_error: 0.0339
# Epoch 85/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0021 - mean_absolute_error: 0.0331
# Epoch 86/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - loss: 0.0020 - mean_absolute_error: 0.0318
# Epoch 87/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - loss: 0.0019 - mean_absolute_error: 0.0313
# Epoch 88/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0021 - mean_absolute_error: 0.0333
# Epoch 89/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 0.0022 - mean_absolute_error: 0.0330
# Epoch 90/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - loss: 0.0021 - mean_absolute_error: 0.0316
# Epoch 91/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - loss: 0.0021 - mean_absolute_error: 0.0329
# Epoch 92/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0023 - mean_absolute_error: 0.0331
# Epoch 93/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - loss: 0.0021 - mean_absolute_error: 0.0320
# Epoch 94/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - loss: 0.0021 - mean_absolute_error: 0.0335
# Epoch 95/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 0.0020 - mean_absolute_error: 0.0331
# Epoch 96/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - loss: 0.0022 - mean_absolute_error: 0.0339
# Epoch 97/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - loss: 0.0022 - mean_absolute_error: 0.0334
# Epoch 98/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 47ms/step - loss: 0.0021 - mean_absolute_error: 0.0332
# Epoch 99/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - loss: 0.0022 - mean_absolute_error: 0.0332
# Epoch 100/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0019 - mean_absolute_error: 0.0320

# %%
model.save('keras_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
test_close.shape
# Out:
# (1097, 1)

# %%
past_100_days = pd.DataFrame(train_close[-100:])

# %%
test_df = pd.DataFrame(test_close)

# %% [markdown]
# **Defining the final dataset for testing by including last 100 coloums of the training dataset to get the prediction from the 1st column of the testing dataset.**
#
# ---

# %%
final_df = pd.concat([past_100_days, test_df], ignore_index=True)

# %%
final_df.head()
# Out:
#              0
# 0  2176.000000
# 1  2177.100098
# 2  2157.449951
# 3  2154.000000
# 4  2149.199951

# %%
input_data = scaler.fit_transform(final_df)
input_data
# Out:
# array([[0.22287462],
#        [0.22324059],
#        [0.21670351],
#        ...,
#        [0.82805765],
#        [0.83100184],
#        [0.84054956]])

# %%
input_data.shape
# Out:
# (1197, 1)

# %% [markdown]
# # Testing the model
#
# ---

# %%
x_test = []
y_test = []
for i in range(100, input_data.shape[0]):
   x_test.append(input_data[i-100: i])
   y_test.append(input_data[i, 0])

# %%
x_test, y_test = np.array(x_test), np.array(y_test)
print(x_test.shape)
print(y_test.shape)
# Out:
# (1097, 100, 1)
# (1097,)

# %% [markdown]
# # Making prediction and plotting the graph of predicted vs actual values
#
# ---

# %%
# Making predictions

y_pred = model.predict(x_test)
# Out:
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step

# %%
y_pred.shape
# Out:
# (1097, 1)

# %%
y_test
# Out:
# array([0.14477951, 0.15477636, 0.15181556, ..., 0.82805765, 0.83100184,
#        0.84054956])

# %%
y_pred
# Out:
# array([[0.20939383],
#        [0.2107817 ],
#        [0.21247748],
#        ...,
#        [0.84856284],
#        [0.8443425 ],
#        [0.8388227 ]], dtype=float32)

# %%
scaler.scale_
# Out:
# array([0.00033267])

# %%
scale_factor = 1/0.00041967
y_pred = y_pred * scale_factor
y_test = y_test * scale_factor

# %%
plt.figure(figsize = (12,6))
plt.plot(y_test, 'b', label = "Original Price")
plt.plot(y_pred, 'r', label = "Predicted Price")
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Model evaluation

# %% [markdown]
# Calculation of mean absolute error

# %%
from sklearn.metrics import mean_absolute_error

mae = mean_absolute_error(y_test, y_pred)
mae_percentage = (mae / np.mean(y_test)) * 100
print("Mean absolute error on test set: {:.2f}%".format(mae_percentage))
# Out:
# Mean absolute error on test set: 5.57%

# %% [markdown]
# Calculation of R2 score

# %%
from sklearn.metrics import r2_score

# Actual values
actual = y_test

# Predicted values
predicted = y_pred

# Calculate the R2 score
r2 = r2_score(actual, predicted)

print("R2 score:", r2)
# Out:
# R2 score: 0.9441595653275272

# %%
# Plotting the R2 score
fig, ax = plt.subplots()
ax.barh(0, r2, color='skyblue')
ax.set_xlim([-1, 1])
ax.set_yticks([])
ax.set_xlabel('R2 Score')
ax.set_title('R2 Score')

# Adding the R2 score value on the bar
ax.text(r2, 0, f'{r2:.2f}', va='center', color='black')

plt.show()

# %%
plt.scatter(actual, predicted)
plt.plot([min(actual), max(actual)], [min(predicted), max(predicted)], 'r--')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title(f'R2 Score: {r2:.2f}')
plt.show()
